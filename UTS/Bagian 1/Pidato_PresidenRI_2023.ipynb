# %%
import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
# !pip install PySastrawi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.6/210.6 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# !pip install Sastrawi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Ganti 'namafile.txt' dengan nama file sebenarnya.
file_path = 'pidato_presidenRI_terkait_Gaza.txt'

# Baca file dan cetak isinya
with open(file_path, 'r') as file:
   isi_berita = file.read()
   print(isi_berita)
# Out:
# Pernyataan Presiden Joko Widodo terkait Tindak Kekerasan di Gaza, Palestina, 19 Oktober 2023
#
# Assalamu’alaikum warahmatullahi wabarakatuh.
# Indonesia mengecam keras tindak kekerasan yang terjadi di Gaza karena telah mengakibatkan penderitaan dan semakin banyaknya korban sipil, termasuk perempuan dan anak.
#
# Indonesia juga mengutuk serangan Israel terhadap Rumah Sakit Al-Ahli, ini jelas pelanggaran terhadap hukum humaniter internasional. Sehingga saya perintahkan Menteri Luar Negeri untuk hadir dalam pertemuan luar biasa para Menlu OKI (Organisasi Kerja Sama Islam) di Jeddah kemarin, serta untuk terus mengupayakan evakuasi WNI yang saat ini masih terkendala kondisi lapangan.
#
# ...

# %%
word_tokens = word_tokenize(isi_berita)
print(word_tokens)
# Out:
# ['Pernyataan', 'Presiden', 'Joko', 'Widodo', 'terkait', 'Tindak', 'Kekerasan', 'di', 'Gaza', ',', 'Palestina', ',', '19', 'Oktober', '2023', 'Assalamu', '’', 'alaikum', 'warahmatullahi', 'wabarakatuh', '.', 'Indonesia', 'mengecam', 'keras', 'tindak', 'kekerasan', 'yang', 'terjadi', 'di', 'Gaza', 'karena', 'telah', 'mengakibatkan', 'penderitaan', 'dan', 'semakin', 'banyaknya', 'korban', 'sipil', ',', 'termasuk', 'perempuan', 'dan', 'anak', '.', 'Indonesia', 'juga', 'mengutuk', 'serangan', 'Israel', 'terhadap', 'Rumah', 'Sakit', 'Al-Ahli', ',', 'ini', 'jelas', 'pelanggaran', 'terhadap', 'hukum', 'humaniter', 'internasional', '.', 'Sehingga', 'saya', 'perintahkan', 'Menteri', 'Luar', 'Negeri', 'untuk', 'hadir', 'dalam', 'pertemuan', 'luar', 'biasa', 'para', 'Menlu', 'OKI', '(', 'Organisasi', 'Kerja', 'Sama', 'Islam', ')', 'di', 'Jeddah', 'kemarin', ',', 'serta', 'untuk', 'terus', 'mengupayakan', 'evakuasi', 'WNI', 'yang', 'saat', 'ini', 'masih', 'terkendala', 'kondisi', 'lapangan', '.',
# ...

# %%
stop_words = set(stopwords.words('indonesian'))
word_tokens_no_stopwords = [w for w in word_tokens if not w in stop_words]
print(word_tokens_no_stopwords)
# Out:
# ['Pernyataan', 'Presiden', 'Joko', 'Widodo', 'terkait', 'Tindak', 'Kekerasan', 'Gaza', ',', 'Palestina', ',', '19', 'Oktober', '2023', 'Assalamu', '’', 'alaikum', 'warahmatullahi', 'wabarakatuh', '.', 'Indonesia', 'mengecam', 'keras', 'tindak', 'kekerasan', 'Gaza', 'mengakibatkan', 'penderitaan', 'banyaknya', 'korban', 'sipil', ',', 'perempuan', 'anak', '.', 'Indonesia', 'mengutuk', 'serangan', 'Israel', 'Rumah', 'Sakit', 'Al-Ahli', ',', 'pelanggaran', 'hukum', 'humaniter', 'internasional', '.', 'Sehingga', 'perintahkan', 'Menteri', 'Luar', 'Negeri', 'hadir', 'pertemuan', 'Menlu', 'OKI', '(', 'Organisasi', 'Kerja', 'Sama', 'Islam', ')', 'Jeddah', 'kemarin', ',', 'mengupayakan', 'evakuasi', 'WNI', 'terkendala', 'kondisi', 'lapangan', '.', 'Indonesia', 'tinggal', 'diam', 'korban', 'sipil', 'berjatuhan', ',', 'ketidakadilan', 'rakyat', 'Palestina', '.', 'Indonesia', 'OKI', 'mengirimkan', 'pesan', 'kuat', 'dunia', 'menghentikan', 'eskalasi', ',', 'menghentikan', 'penggunaan', 'kekerasan'
# ...

# %%
freq_kata_1 = nltk.FreqDist(word_tokens)
freq_kata_2 = nltk.FreqDist(word_tokens_no_stopwords)
print(freq_kata_1.most_common(10))
print()
print(freq_kata_2.most_common(10))
# Out:
# [(',', 12), ('.', 10), ('dan', 6), ('untuk', 6), ('di', 5), ('Indonesia', 5), ('Palestina', 4), ('yang', 4), ('terus', 4), ('terhadap', 3)]
#
# [(',', 12), ('.', 10), ('Indonesia', 5), ('Palestina', 4), ('internasional', 3), ('Gaza', 2), ('’', 2), ('alaikum', 2), ('warahmatullahi', 2), ('wabarakatuh', 2)]

# %%
import matplotlib.pyplot as plt

# %%
freq_kata_1.plot(10)
freq_kata_2.plot(10)
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from collections import Counter

# Baca teks pidato dari file
with open('pidato_presidenRI_terkait_Gaza.txt', 'r', encoding='utf-8') as file:
    pidato = file.read()

# Tokenisasi teks
tokens = word_tokenize(pidato)

# Hapus kata-kata stopwords (kata-kata umum yang tidak memberikan makna khusus)
stop_words = set(stopwords.words('indonesian'))
filtered_tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]

# Hitung frekuensi kata-kata
word_freq = Counter(filtered_tokens)

# Ambil 20 kata yang paling sering muncul
common_words = word_freq.most_common(20)

# Siapkan data untuk plot
words, frequencies = zip(*common_words)

# Plot kata-kata yang paling sering muncul
plt.figure(figsize=(12, 6))
plt.bar(words, frequencies)
plt.xlabel('Kata-kata')
plt.ylabel('Frekuensi')
plt.title('10 Kata Paling Sering Muncul dalam Pidato')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Jadi 10 kata yang sering muncuk yaitu Indonesia, Palestina, kekerasan, Internasional, tindak, Gaza, alaikum, warahmatullahi, wabarakatuh,korban, sipil,Israel, mentri, Oki, dunia, menghentikan menyelesaikan,pernyataan prseiden, dan Joko.
#
# Dalam pidato nya presiden RI Joko Widodo Indonesia mengecam keras tindak kekerasan yang terjadi di Gaza karena telah mengakibatkan penderitaan dan semakin banyaknya korban sipil, termasuk perempuan dan anak.
#
# Indonesia juga mengutuk serangan Israel terhadap Rumah Sakit Al-Ahli, ini jelas pelanggaran terhadap hukum humaniter internasional. Sehingga saya perintahkan Menteri Luar Negeri untuk hadir dalam pertemuan luar biasa para Menlu OKI (Organisasi Kerja Sama Islam) di Jeddah kemarin, serta untuk terus mengupayakan evakuasi WNI yang saat ini masih terkendala kondisi lapangan.
