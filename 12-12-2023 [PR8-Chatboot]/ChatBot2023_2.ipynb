# %%
import json
import string
import random
import nltk
nltk.download('omw-1.4')
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
ourData = {
    "ourIntents":
     [

    {"tag": "greeting",
     "patterns": ["Hi", "Hello", "Hey"],
     "responses": ["Welcome to our online store! How may I assist you?", "Hello! How can I help you today?", "Hi there! How may we serve you?"],
    },

    {"tag": "product_inquiry",
     "patterns": ["Tell me about the products you offer", "What items are available?", "Show me your product catalog"],
     "responses": ["Explore our diverse product range, featuring electronics, clothing, accessories, and more. Feel free to browse our catalog on our website!"],
    },

    {"tag": "price_inquiry",
     "patterns": ["What is the cost?", "How much does it cost?", "Can you tell me the price?"],
     "responses": ["For the most up-to-date pricing information, please visit our website or reach out to our customer support. Prices may vary based on promotions and product availability."],
    },

    {"tag": "shipping_info",
     "patterns": ["Tell me about your shipping services", "How does the shipping process work?", "Provide information about delivery"],
     "responses": ["We offer reliable and timely shipping services. Shipping fees and delivery times may vary based on your location. Find more details during the checkout process."],
    },

    {"tag": "payment_info",
     "patterns": ["What are the payment options?", "Tell me about accepted payment methods", "How can I make a payment?"],
     "responses": ["We accept various payment methods, including credit cards, PayPal, and more. You can choose the payment option that best suits you during the checkout process."],
    },

    {"tag": "discounts",
     "patterns": ["Are there any discounts?", "Tell me about promotions", "Discount offers"],
     "responses": ["Yes, we frequently offer promotions and discounts. Check our website or subscribe to our newsletter to stay updated on the latest deals!"],
    },

    {"tag": "order_status",
     "patterns": ["Check my order status", "Where is my package?", "Track my order"],
     "responses": ["To check your order status, please log in to your account on our website. There, you can find real-time updates on your order and shipment."],
    },

    {"tag": "returns",
     "patterns": ["Can I return a product?", "What is your return policy?", "Return process"],
     "responses": ["We have a hassle-free return policy. If you're not satisfied with your purchase, you can initiate a return within [number of days] days of receiving the product. Visit our Returns page on the website for more details."],
    },

    {"tag": "contact_support",
     "patterns": ["How can I contact customer support?", "Need help", "Customer service contact"],
     "responses": ["Our customer support team is here to assist you. You can reach us through [email], our helpline at [phone number], or use the live chat feature on our website."],
    },

    {"tag": "order_history",
     "patterns": ["View my order history", "Previous orders", "Order records"],
     "responses": ["To view your order history, log in to your account and navigate to the Order History section. There, you can find a detailed record of all your past orders."],
    },
    {"tag": "goodbye",
     "patterns": ["bye", "see you later", "goodbye"],
     "responses": ["Thank you for visiting our online store! If you have any further questions, feel free to ask. Goodbye!", "Goodbye! Have a wonderful day!"],
    }

   ]
}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["ourIntents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.Adam(learning_rate=0.005)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 128)               8448
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 11)                715
#
# =================================================================
# Total params: 17419 (68.04 KB)
# Trainable params: 17419 (68.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 2/2 [==============================] - 1s 8ms/step - loss: 2.4641 - accuracy: 0.0303
# Epoch 2/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4512 - accuracy: 0.0606
# Epoch 3/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.3059 - accuracy: 0.1818
# Epoch 4/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2419 - accuracy: 0.2424
# Epoch 5/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1298 - accuracy: 0.3030
# Epoch 6/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1547 - accuracy: 0.3333
# Epoch 7/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9988 - accuracy: 0.3636
# Epoch 8/200
# 2/2 [==============================] - 0s 7ms/step - loss: 2.0231 - accuracy: 0.4242
# Epoch 9/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8448 - accuracy: 0.5455
# Epoch 10/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.7593 - accuracy: 0.6061
# Epoch 11/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6841 - accuracy: 0.6667
# Epoch 12/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.5850 - accuracy: 0.5455
# Epoch 13/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4552 - accuracy: 0.7879
# Epoch 14/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4756 - accuracy: 0.6970
# Epoch 15/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.4589 - accuracy: 0.7879
# Epoch 16/200
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1689 - accuracy: 0.7273
# Epoch 17/200
# 2/2 [==============================] - 0s 11ms/step - loss: 1.1824 - accuracy: 0.7576
# Epoch 18/200
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0648 - accuracy: 0.7273
# Epoch 19/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9899 - accuracy: 0.7879
# Epoch 20/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9666 - accuracy: 0.7273
# Epoch 21/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.8578 - accuracy: 0.8485
# Epoch 22/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6291 - accuracy: 0.8485
# Epoch 23/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7874 - accuracy: 0.8182
# Epoch 24/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6499 - accuracy: 0.9091
# Epoch 25/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5390 - accuracy: 0.9091
# Epoch 26/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5074 - accuracy: 0.8788
# Epoch 27/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.7707 - accuracy: 0.8182
# Epoch 28/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4118 - accuracy: 0.9394
# Epoch 29/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3930 - accuracy: 0.8788
# Epoch 30/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3517 - accuracy: 1.0000
# Epoch 31/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2313 - accuracy: 1.0000
# Epoch 32/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3729 - accuracy: 0.9394
# Epoch 33/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2871 - accuracy: 0.9697
# Epoch 34/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3551 - accuracy: 0.9091
# Epoch 35/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2871 - accuracy: 0.9697
# Epoch 36/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1982 - accuracy: 0.9697
# Epoch 37/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2231 - accuracy: 1.0000
# Epoch 38/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3508 - accuracy: 0.8182
# Epoch 39/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.1770 - accuracy: 1.0000
# Epoch 40/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1648 - accuracy: 0.9697
# Epoch 41/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2077 - accuracy: 0.9394
# Epoch 42/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1117 - accuracy: 1.0000
# Epoch 43/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1353 - accuracy: 1.0000
# Epoch 44/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1130 - accuracy: 1.0000
# Epoch 45/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1578 - accuracy: 0.9697
# Epoch 46/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0884 - accuracy: 1.0000
# Epoch 47/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0829 - accuracy: 1.0000
# Epoch 48/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0976 - accuracy: 1.0000
# Epoch 49/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0810 - accuracy: 1.0000
# Epoch 50/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0581 - accuracy: 1.0000
# Epoch 51/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1224 - accuracy: 0.9697
# Epoch 52/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0607 - accuracy: 1.0000
# Epoch 53/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0548 - accuracy: 1.0000
# Epoch 54/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 55/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0940 - accuracy: 1.0000
# Epoch 56/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0876 - accuracy: 1.0000
# Epoch 57/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0885 - accuracy: 0.9697
# Epoch 58/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0824 - accuracy: 0.9697
# Epoch 59/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0492 - accuracy: 1.0000
# Epoch 60/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1011 - accuracy: 1.0000
# Epoch 61/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 62/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 63/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 64/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0682 - accuracy: 1.0000
# Epoch 65/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0704 - accuracy: 0.9697
# Epoch 66/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0811 - accuracy: 1.0000
# Epoch 67/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0652 - accuracy: 1.0000
# Epoch 68/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 69/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 70/200
# 2/2 [==============================] - 0s 17ms/step - loss: 0.1359 - accuracy: 0.9697
# Epoch 71/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0669 - accuracy: 1.0000
# Epoch 72/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0973 - accuracy: 0.9697
# Epoch 73/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 74/200
# 2/2 [==============================] - 0s 19ms/step - loss: 0.1079 - accuracy: 0.9697
# Epoch 75/200
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 76/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0703 - accuracy: 0.9697
# Epoch 77/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 78/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 79/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 80/200
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 81/200
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 82/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0545 - accuracy: 0.9697
# Epoch 83/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1457 - accuracy: 0.9697
# Epoch 84/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 85/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 86/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1417 - accuracy: 0.9697
# Epoch 87/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0426 - accuracy: 1.0000
# Epoch 88/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 89/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 90/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 91/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 92/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 93/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 94/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0622 - accuracy: 0.9697
# Epoch 95/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 96/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 97/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 98/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 99/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 100/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 101/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0746 - accuracy: 0.9697
# Epoch 102/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 103/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 104/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0552 - accuracy: 0.9697
# Epoch 105/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 106/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 107/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 108/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0335 - accuracy: 1.0000
# Epoch 109/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0408 - accuracy: 1.0000
# Epoch 110/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 111/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 112/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 113/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0438 - accuracy: 0.9697
# Epoch 114/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 115/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0305 - accuracy: 0.9697
# Epoch 116/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 117/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 118/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 119/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 120/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 121/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 122/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0531 - accuracy: 0.9697
# Epoch 123/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0563 - accuracy: 0.9697
# Epoch 124/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 125/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 126/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0781 - accuracy: 0.9697
# Epoch 127/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 128/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0312 - accuracy: 0.9697
# Epoch 129/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 130/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 131/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 132/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0465 - accuracy: 1.0000
# Epoch 133/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 134/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 135/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 136/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 137/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 138/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 139/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 140/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0685 - accuracy: 0.9697
# Epoch 141/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 142/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 143/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 144/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 145/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 146/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 147/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 148/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 149/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 150/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 151/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 152/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0327 - accuracy: 0.9697
# Epoch 153/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 154/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0552 - accuracy: 0.9697
# Epoch 155/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0855 - accuracy: 0.9697
# Epoch 156/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 157/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0437 - accuracy: 0.9697
# Epoch 158/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 159/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 160/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 161/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 162/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 163/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 164/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 165/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 166/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 167/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 168/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 169/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 170/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 171/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 172/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 173/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 174/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 175/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 176/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 177/200
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 178/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 179/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 180/200
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 181/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 182/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 183/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 184/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 185/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 186/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 187/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 188/200
# 2/2 [==============================] - 0s 12ms/step - loss: 9.4539e-04 - accuracy: 1.0000
# Epoch 189/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 190/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 191/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 192/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 193/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 194/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 195/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 196/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 198/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0732 - accuracy: 0.9697
# Epoch 199/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 200/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0047 - accuracy: 1.0000

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["ourIntents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
while True:
    newMessage = input("")

    # Tentukan kondisi untuk menghentikan loop
    if newMessage.lower() == "exit":
        break

    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, ourData)
    print(ourResult)
# Out:
# hi
# 1/1 [==============================] - 0s 64ms/step
# Hi there! How may we serve you?
# item are available
# 1/1 [==============================] - 0s 30ms/step
# Explore our diverse product range, featuring electronics, clothing, accessories, and more. Feel free to browse our catalog on our website!
# what is the cost?
# 1/1 [==============================] - 0s 21ms/step
# For the most up-to-date pricing information, please visit our website or reach out to our customer support. Prices may vary based on promotions and product availability.
# shipping info
# 1/1 [==============================] - 0s 21ms/step
# We offer reliable and timely shipping services. Shipping fees and delivery times may vary based on your location. Find more details during the checkout process.
# payment?
# 1/1 [==============================] - 0s 21ms/step
# We accept various payment methods, including credit cards, PayPal, and more. You can choose the payment option that best suits you during the checkout process.
# any discounts?
# 1/1 [==============================] - 0s 20ms/step
# Yes, we frequently offer promotions and discounts. Check our website or subscribe to our newsletter to stay updated on the latest deals!
# check my order status!
# 1/1 [==============================] - 0s 21ms/step
# To check your order status, please log in to your account on our website. There, you can find real-time updates on your order and shipment.
# Can I return a product?
# 1/1 [==============================] - 0s 22ms/step
# We have a hassle-free return policy. If you're not satisfied with your purchase, you can initiate a return within [number of days] days of receiving the product. Visit our Returns page on the website for more details.
# order records
# 1/1 [==============================] - 0s 22ms/step
# To view your order history, log in to your account and navigate to the Order History section. There, you can find a detailed record of all your past orders.
# oke bye
# 1/1 [==============================] - 0s 21ms/step
# Thank you for visiting our online store! If you have any further questions, feel free to ask. Goodbye!
# exit
